# %%
#0301
from tensorflow.python.framework.ops import disable_eager_execution

import tensorflow as tf

print(tf.executing_eagerly())
disable_eager_execution()
print(tf.executing_eagerly())

# Graph construction
a = tf.constant(1)
b = tf.constant(2)
c = a + b  # c= tf.add(a, b)
print(a)
print(b)
print(c)
 

#2 graph execution
sess = tf.compat.v1.Session()
print(sess.run(a))
print(sess.run(b))
print(sess.run(c))
sess.close()
# Out:
# True
# False
# Tensor("Const:0", shape=(), dtype=int32)
# Tensor("Const_1:0", shape=(), dtype=int32)
# Tensor("add:0", shape=(), dtype=int32)
# 1
# 2
# 3

# %%
#0302
from tensorflow.python.framework.ops import enable_eager_execution
##enable_eager_execution()
import tensorflow as tf

# 해당 코드 기재해야 tf.executing_eagerly() 값이 True로 변경되고 정상실행됨
tf.compat.v1.enable_v2_behavior() # 런타임 재시작 필요

print(tf.executing_eagerly())
a = tf.constant(1)
b = tf.constant(2)
c = a + b   # c= tf.add(a, b)
print(a)
print(b)
print(c)
print(a.numpy(), b.numpy(), c.numpy())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7244\2525756204.py in <module>
#       5
#       6 # 해당 코드 기재해야 tf.executing_eagerly() 값이 True로 변경되고 정상실행됨
# ----> 7 tf.compat.v1.enable_v2_behavior() # 런타임 재시작 필요
#       8
#       9 print(tf.executing_eagerly())
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\compat\v2_compat.py in enable_v2_behavior()
#      58   # the modules below independently check if tf2.enabled().
#      59   tf2.enable()
# ---> 60   ops.enable_eager_execution()
#      61   tensor_shape.enable_v2_tensorshape()  # Also switched by tf2
#      62   variable_scope.enable_resource_variables()
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\ops.py in enable_eager_execution(config, device_policy, execution_mode)
#    6153   logging.vlog(1, "Enabling eager execution")
#    6154   if context.default_execution_mode != context.EAGER_MODE:
# -> 6155     return enable_eager_execution_internal(
#    6156         config=config,
#    6157         device_policy=device_policy,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\ops.py in enable_eager_execution_internal(config, device_policy, execution_mode, server_def)
#    6221         _default_graph_stack._global_default_graph is not None)  # pylint: disable=protected-access
#    6222     if graph_mode_has_been_used:
# -> 6223       raise ValueError(
#    6224           "tf.enable_eager_execution must be called at program startup.")
#    6225   context.default_execution_mode = context.EAGER_MODE
#
# ValueError: tf.enable_eager_execution must be called at program startup.

# %%
#0303
import tensorflow as tf
#1
a = tf.constant(1)
b = tf.constant([1, 2, 3, 4])
c = tf.constant([[1, 2], [3, 4]])
d = tf.constant([[[1, 2], [3, 4]]])

#2
print(a)
print(a.dtype)
print(a.ndim, b.ndim, c.ndim, d.ndim)
print(a.shape, b.shape, c.shape, d.shape)

#3: indexing, slicing
print(b[0])
print(b[:2])
print(c[0, 0])
print(c[:,0])
# Out:
# Tensor("Const_6:0", shape=(), dtype=int32)
# <dtype: 'int32'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7244\3496949969.py in <module>
#      10 print(a)
#      11 print(a.dtype)
# ---> 12 print(a.ndim, b.ndim, c.ndim, d.ndim)
#      13 print(a.shape, b.shape, c.shape, d.shape)
#      14
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\ops.py in __getattr__(self, name)
#     442         np_config.enable_numpy_behavior()
#     443       """)
# --> 444     self.__getattribute__(name)
#     445
#     446   @staticmethod
#
# AttributeError: 'Tensor' object has no attribute 'ndim'

# %%
#0304
import tensorflow as tf
#1
a = tf.Variable(1)
b = tf.Variable([1, 2, 3, 4])
c = tf.Variable([[1, 2], [3, 4]])
d = tf.Variable([[[1, 2], [3, 4]]])
print(a.dtype)
print(a.shape, b.shape, c.shape, d.shape)
 
#2
print(a)
print(a.read_value()) # a.value()
print(a.trainable)

#3: indexing, slicing
print(b[0])
print(b[:2])
print(c[0, 0])
print(c[:,0])

#4: assign(), assign_add(), assign_sub()
print(id(a))
print(a.assign(10)) # a.assign(20, read_value=False) : no return
print(a.assign_add(20))
print(a.assign_sub(10))
print(id(a))
# Out:
# <dtype: 'int32'>
# () (4,) (2, 2) (1, 2, 2)
# <tf.Variable 'Variable:0' shape=() dtype=int32>
# Tensor("Identity:0", shape=(), dtype=int32)
# True
# Tensor("strided_slice:0", shape=(), dtype=int32)
# Tensor("strided_slice_1:0", shape=(2,), dtype=int32)
# Tensor("strided_slice_2:0", shape=(), dtype=int32)
# Tensor("strided_slice_3:0", shape=(2,), dtype=int32)
# 1810262428448
# <tf.Variable 'AssignVariableOp' shape=() dtype=int32>
# <tf.Variable 'AssignAddVariableOp' shape=() dtype=int32>
# <tf.Variable 'AssignSubVariableOp' shape=() dtype=int32>
# 1810262428448

# %%
#0305
import tensorflow as tf

a = tf.zeros(shape = (2, 3)) # dtype = tf.float32
print(a)

b = tf.ones(shape = (2, 3))
print(b)

c = tf.zeros_like(b)
print(c)

d = tf.ones_like(c)
print(d)

w = tf.Variable( d )
print(w)
# Out:
# Tensor("zeros:0", shape=(2, 3), dtype=float32)
# Tensor("ones:0", shape=(2, 3), dtype=float32)
# Tensor("zeros_like:0", shape=(2, 3), dtype=float32)
# Tensor("ones_like:0", shape=(2, 3), dtype=float32)
# <tf.Variable 'Variable_4:0' shape=(2, 3) dtype=float32>

# %%
#0306  해당 함수가 뭔지 알아야함
import tensorflow as tf

a= tf.fill([2, 3], 2.0)
print(a)

b = tf.linspace(0.0, 1.0, 5)
print(b)

c = tf.range(5)
print(c)

d = tf.range(1, 5, 0.5)
print(d)

w = tf.Variable(d)
print(w)
# Out:
# Tensor("Fill:0", shape=(2, 3), dtype=float32)
# Tensor("linspace/Slice:0", shape=(5,), dtype=float32)
# Tensor("range:0", shape=(5,), dtype=int32)
# Tensor("range_1:0", shape=(8,), dtype=float32)
# <tf.Variable 'Variable_5:0' shape=(8,) dtype=float32>

# %%
#0307
import tensorflow as tf
#1
a = tf.range(6)
print(a)

b = tf.reshape(a, shape=(2, 3)) # tf.reshape(a, shape=(-1, 3))
print(b)

# 많이 사용되므로 확실히 알기
c = tf.reshape(b, shape=(-1,))
print(c)

#2
d = tf.transpose(b) # tf.transpose(b, perm=[1, 0])
print(d)
# Out:
# Tensor("range_2:0", shape=(6,), dtype=int32)
# Tensor("Reshape:0", shape=(2, 3), dtype=int32)
# Tensor("Reshape_1:0", shape=(6,), dtype=int32)
# Tensor("transpose:0", shape=(3, 2), dtype=int32)

# %%
#0308
import tensorflow as tf

#1
a = tf.constant([1, 2])  # [1, 2]
b = tf.constant([3, 4])  # [3, 4]

#2
print(tf.stack([a, b])) # axis = 0
print(tf.stack([a, b], axis = 1))
 
#3
print(tf.concat([a, b],axis =0))
a = tf.reshape(a, shape=(1,2))
b = tf.reshape(b, shape=(1,2))
c = tf.concat([a, b],axis =0)
print(c)
 
print(tf.concat([a, b],axis =1))
print(tf.concat([c, b],axis =0))

b = tf.reshape(b, shape=(2,1))
print(b)

print(tf.concat([c, b],axis =1))

# %%
#0309
import tensorflow as tf
#1
a = tf.constant([1, 2])
print(a)

b = tf.expand_dims(a, axis = 0)
print(b)

c = tf.expand_dims(a, axis = 1)
print(c)

d = tf.expand_dims(c, axis = 0)
print(d)

#2
e = tf.squeeze(d) # remove all axes of shape size = 1
print(e)

f = tf.squeeze(d, axis = 2)
print(f)
# Out:
# Tensor("Const_13:0", shape=(2,), dtype=int32)
# Tensor("ExpandDims:0", shape=(1, 2), dtype=int32)
# Tensor("ExpandDims_1:0", shape=(2, 1), dtype=int32)
# Tensor("ExpandDims_2:0", shape=(1, 2, 1), dtype=int32)
# Tensor("Squeeze:0", shape=(2,), dtype=int32)
# Tensor("Squeeze_1:0", shape=(1, 2), dtype=int32)

# %%
#0310
import tensorflow as tf

tf.random.set_seed(1)
a = tf.range(5)
print(tf.random.shuffle(a))
print(tf.random.uniform(shape=(2, 3), minval=0, maxval=1))
print(tf.random.normal(shape=(2,3))) # mean=0, stddev=1
print(tf.random.normal(shape=(2,3), mean=10, stddev=2))
print(tf.random.truncated_normal(shape=(2, 3))) # mean=0, stddev=1

w= tf.Variable(tf.random.truncated_normal(shape=(2, 3)))
print(w)
# Out:
# Tensor("RandomShuffle:0", shape=(5,), dtype=int32)
# Tensor("random_uniform/RandomUniform:0", shape=(2, 3), dtype=float32)
# Tensor("random_normal:0", shape=(2, 3), dtype=float32)
# Tensor("random_normal_1:0", shape=(2, 3), dtype=float32)
# Tensor("truncated_normal:0", shape=(2, 3), dtype=float32)
# <tf.Variable 'Variable_6:0' shape=(2, 3) dtype=float32>

# %%
#0401
import tensorflow as tf
#1
a = tf.constant([1, 2])
print(a + 1) # tf.add(a, 1), tf.math.add(a, 1)
print(a - 1) # tf.subtract(a, 1), tf.math.subtract(a, 1)
print(a * 2) # tf.multiply(a, 2), tf.math.multiply(a, 2)
print(a / 2) # tf.divide(a, 2), tf.math.divide(a, 2)

#2
b = tf.constant([3, 4])
print(a + b) # tf.add(a, b)
print(a - b) # tf.subtract(a, b)
print(a * b) # tf.multiply(a, b)
print(a / b)  # tf.divide(a, b)

#3
a = tf.constant([[1, 2], [3, 4]])
b = tf.constant([1, 2])
print(a + b) # tf.add(a, b)
print(a - b) # tf.subtract(a, b)
print(a * b) # tf.multiply(a, b)
print(a / b) # tf.divide(a, b)
# Out:
# Tensor("add_1:0", shape=(2,), dtype=int32)
# Tensor("sub:0", shape=(2,), dtype=int32)
# Tensor("mul:0", shape=(2,), dtype=int32)
# Tensor("truediv:0", shape=(2,), dtype=float64)
# Tensor("add_2:0", shape=(2,), dtype=int32)
# Tensor("sub_1:0", shape=(2,), dtype=int32)
# Tensor("mul_1:0", shape=(2,), dtype=int32)
# Tensor("truediv_1:0", shape=(2,), dtype=float64)
# Tensor("add_3:0", shape=(2, 2), dtype=int32)
# Tensor("sub_2:0", shape=(2, 2), dtype=int32)
# Tensor("mul_2:0", shape=(2, 2), dtype=int32)
# Tensor("truediv_2:0", shape=(2, 2), dtype=float64)

# %%
#0402
import tensorflow as tf
#1
a = tf.reshape(tf.range(12), shape = (3, 4))
print(a)

#2 
print(tf.reduce_min(a))
print(tf.reduce_min(a, axis= 0))
print(tf.reduce_min(a, axis= 1))

#3
print(tf.reduce_max(a))
print(tf.reduce_max(a, axis= 0))
print(tf.reduce_max(a, axis= 1))

#4
print(tf.reduce_sum(a))
print(tf.reduce_sum(a, axis= 0))
print(tf.reduce_sum(a, axis= 1))

#5
print(tf.reduce_mean(a))
print(tf.reduce_mean(a, axis= 0))
print(tf.reduce_mean(a, axis= 1))

#6
print(tf.reduce_prod(a))
print(tf.reduce_prod(a, axis= 0))
print(tf.reduce_prod(a, axis= 1))

#7
a = tf.reshape(tf.random.shuffle(tf.range(12)), shape = (3, 4))
print(a)

print(tf.argmin(a)) #  tf.argmin(a, axis =0)
print(tf.argmin(a, axis =1))
print(tf.argmax(a)) # tf.argmax(a, axis =0)
print(tf.argmax(a, axis =1))

#8
a = tf.random.shuffle(tf.range(12))
print(a)
print(tf.sort(a)) # direction="ASCENDING"
print(tf.sort(a, direction="DESCENDING"))

a = tf.reshape(a, shape=(3, 4))
print(a)
print(tf.sort(a)) # tf.sort(a, axis = 1)
print(tf.sort(a, axis = 0))
# Out:
# Tensor("Reshape_2:0", shape=(3, 4), dtype=int32)
# Tensor("Min:0", shape=(), dtype=int32)
# Tensor("Min_1:0", shape=(4,), dtype=int32)
# Tensor("Min_2:0", shape=(3,), dtype=int32)
# Tensor("Max:0", shape=(), dtype=int32)
# Tensor("Max_1:0", shape=(4,), dtype=int32)
# Tensor("Max_2:0", shape=(3,), dtype=int32)
# Tensor("Sum:0", shape=(), dtype=int32)
# Tensor("Sum_1:0", shape=(4,), dtype=int32)
# Tensor("Sum_2:0", shape=(3,), dtype=int32)
# Tensor("Mean:0", shape=(), dtype=int32)
# Tensor("Mean_1:0", shape=(4,), dtype=int32)
# Tensor("Mean_2:0", shape=(3,), dtype=int32)
# Tensor("Prod:0", shape=(), dtype=int32)
# Tensor("Prod_1:0", shape=(4,), dtype=int32)
# Tensor("Prod_2:0", shape=(3,), dtype=int32)
# Tensor("Reshape_3:0", shape=(3, 4), dtype=int32)
# Tensor("ArgMin:0", shape=(4,), dtype=int64)
# Tensor("ArgMin_1:0", shape=(3,), dtype=int64)
# Tensor("ArgMax:0", shape=(4,), dtype=int64)
# Tensor("ArgMax_1:0", shape=(3,), dtype=int64)
# Tensor("RandomShuffle_2:0", shape=(12,), dtype=int32)
# Tensor("sort/sub_1:0", shape=(12,), dtype=int32)
# Tensor("sort_1/TopKV2:0", shape=(12,), dtype=int32)
# Tensor("Reshape_4:0", shape=(3, 4), dtype=int32)
# Tensor("sort_2/sub_1:0", shape=(3, 4), dtype=int32)
# Tensor("sort_3/sub_1:0", shape=(3, 4), dtype=int32)

# %%
#0403
import tensorflow as tf
#1
a = tf.constant([1, 2, 3], dtype=tf.float32)
print(tf.norm(a)) # tf.linalg.norm(a)

#2
A = tf.constant([[1, 2], [3, 4]], dtype=tf.float32)
print(tf.linalg.matrix_transpose(A))

#3
print(tf.linalg.det(A))

B =  tf.linalg.inv(A) 
print(B)
print(tf.matmul(A, B))  # tf.linalg.matmul(A, B)
# Out:
# Tensor("norm/Squeeze:0", shape=(), dtype=float32)
# Tensor("matrix_transpose/transpose:0", shape=(2, 2), dtype=float32)
# Tensor("MatrixDeterminant:0", shape=(), dtype=float32)
# Tensor("MatrixInverse:0", shape=(2, 2), dtype=float32)
# Tensor("MatMul:0", shape=(2, 2), dtype=float32)

# %%
#0404
import tensorflow as tf
#1
A = tf.constant([[1, 4,  1],
	         [1, 6, -1],
		 [2, -1, 2]], dtype=tf.float32)
b = tf.constant([[ 7],
                 [13],
                 [ 5]], dtype=tf.float32)

#2
print(tf.linalg.det(A))

x = tf.matmul(tf.linalg.inv(A), b)
print(x)

#3
def all_close(x, y, tol=1e-5):
#	return tf.reduce_sum(tf.abs(x - y)) < tol
         return tf.reduce_sum(tf.square(x - y)) < tol
print(all_close(tf.matmul(A, x), b))

#4
x = tf.linalg.solve(A, b)
print(x)
print(all_close(tf.matmul(A, x), b))
# Out:
# Tensor("MatrixDeterminant_1:0", shape=(), dtype=float32)
# Tensor("MatMul_1:0", shape=(3, 1), dtype=float32)
# Tensor("Less:0", shape=(), dtype=bool)
# Tensor("MatrixSolve:0", shape=(3, 1), dtype=float32)
# Tensor("Less_1:0", shape=(), dtype=bool)

# %%
#0405
import tensorflow as tf
#1
A = tf.constant([[1, 4,  1],
 	         [1, 6, -1],
		 [2, -1, 2]], dtype=tf.float32)
L_U, p = tf.linalg.lu(A)
print(L_U)
print(p)

#2: make P, L, U
U = tf.linalg.band_part(L_U, 0, -1) # Upper triangular
print(U)

L = tf.linalg.band_part(L_U, -1, 0) # Lower triangular
print(L)
L = tf.linalg.set_diag(L, [1, 1, 1]) # strictly lower triangular part of LU
print(L)

P = tf.gather(tf.eye(3), p)
print(P)

#3: check A= PLU 
#3-1:
print(tf.linalg.lu_reconstruct(L_U, p))

#3-2: calculate directly the same as #3-1
print(tf.matmul(P, tf.matmul(L, U))) # tf.gather(tf.matmul(L, U), p)

#4: solve AX = b using PLUx = b
b = tf.constant([[ 7],
                 [13],
                 [ 5]], dtype=tf.float32)
#4-1:
print(tf.linalg.lu_solve(L_U, p, b))


#4-2: calculate directly the same as #4-1
y = tf.linalg.triangular_solve(L, tf.matmul(tf.transpose(P), b))
print(y)

x = tf.linalg.triangular_solve(U, y, lower=False)
print(x)

#5: stuff: pivots, calulate det(A), rank(A)
D = tf.linalg.diag_part(L_U) # tf.linalg.diag_part(U)
print(D)

rank = tf.math.count_nonzero(D)
print(rank)

det_U = tf.reduce_prod(tf.linalg.diag_part(U)) # tf.linalg.det(U)
print(det_U)

det_L = tf.reduce_prod(tf.linalg.diag_part(L)) # # tf.linalg.det(L)  
print(det_L)

det_P = tf.linalg.det(P)
print(det_P)

det_A = det_P*det_L*det_U # tf.linalg.det(A)
print(det_A)

# %%
#0406
import tensorflow as tf
#1
A = tf.constant([[0, 1],
		 [1, 1],
		 [2, 1]], dtype=tf.float32)
b = tf.constant([[ 6],
                 [ 0],
                 [ 0]], dtype=tf.float32)
At = tf.transpose(A)
C = tf.matmul(At, A)
print(C)

#2
x = tf.linalg.solve(C, tf.matmul(At, b))
print(x)

#3
x2 = tf.matmul(tf.matmul(tf.linalg.inv(C), At), b)
print(x2)

#4
L_U, p = tf.linalg.lu(C)
x3 = tf.linalg.lu_solve(L_U, p, tf.matmul(At, b))
print(x3)

#4 
x4 = tf.linalg.lstsq(A, b)
print(x4)

# draw the line
m, c = x.numpy()[:,0]
import matplotlib.pyplot as plt
plt.gca().set_aspect('equal')
plt.scatter(x = A.numpy()[:,0], y = b.numpy())
t = tf.linspace(-1.0, 3.0, num=51)
b1 = m*t + c
plt.plot(t, b1, "b-")
plt.axis([-1, 10, -1, 10])
plt.show()

# %%
#0407
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

#1
def f(x):
    return x**4 - 3*x**3 +2

# 미분
def fprime(x): # forward difference
    h = 0.001
    return (f(x+h) - f(x))/h

#2
k = 0
max_iters = 1000
lr = 0.001 
tol = 1e-5

x_old = 0.0
x_new = 4.0  # -2.0
x_list= [x_new]  # list of x_new
x = tf.Variable(x_new, dtype = tf.float32) # initial value

# 기울기 계산
while abs(x_old-x_new)>tol and  k < max_iters:
    k+=1
    x_old= x.numpy()
    step = lr * fprime(x)
    x.assign_sub(step, read_value=False) # update value by gradient decent method 
    x_new= x.numpy()
    x_list.append(x_new)
##    print('k={}: f({})={}'.format(k, x_new, f(x_new)))
print('k={}: f({})={}'.format(k, x_new, f(x_new))) # final solution

#3: check solutions
print("[f(0), f(9/4), f(-2), f(4)]=", [f(0), f(9/4), f(-2), f(4)])
# [f(0), f(9/4), f(-2), f(4)]: [2, -6.54296875, 42, 66] 

#4: draw graph 
#4-1: graph f(x)
##x_values = np.linspace(-2.0, 4.0, num = 101) # numpy.ndarray
xs = tf.linspace(-2.0, 4.0, num = 101) # Tensor  
ys = f(xs)
plt.plot(xs, ys,  'b-')

#4-2: f(x_new), updated solutions
##x_list =np.array(x_list) # numpy.ndarray
x_list =tf.constant(x_list, dtype=tf.float32)  # Tensor
y_list = f(x_list) 
plt.plot(x_list, y_list, 'ro')
plt.show()
